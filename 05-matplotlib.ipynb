# %% [markdown]
# ## Matplotlib

# %%
# Versão da Linguagem Python

from platform import python_version
print('Versão de Python Neste Jupyter Notebook:', python_version())
# Out:
# Versão de Python Neste Jupyter Notebook: 3.10.5

# %%
#imports necessários

import numpy as np                    # manipulação numerica
import matplotlib.pyplot as plt       # visualização gráfica
import matplotlib
from numpy.random import randint


import warnings                       # silecio de alertas
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# o pacote watermark adiciona um logotipo ao nosso notebook com as versões dos pacotes utilizados

# %reload_ext watermark
# %watermark -a "Caique Miranda" -gu caiquemiranda

print(f'Versão do Numpy {np.__version__}')
print(f'Versão do Matplotlib {matplotlib.__version__}')
# Out:
# Author: Caique Miranda
#
# Github username: caiquemiranda
#
# Versão do Numpy 1.23.0
# Versão do Matplotlib 3.5.2

# %% [markdown]
# ### Plot

# %%
# !pip install matplotlib

# %%
x = np.linspace(1, 10, 20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1, 50, 20)
y
# Out:
# array([24, 33, 37, 40, 28,  4, 22, 28, 29, 39, 13, 25, 46, 12, 44, 48, 49,
#        46,  4, 31])

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
plt.plot(y);

# %%
y = y.cumsum()

# %%
plt.plot(y);

# %%
plt.plot(x, y);

# %%
plt.plot(x, y, 
         color = 'g',
         marker = 'o',
         linestyle = '--');

# %% [markdown]
# ### Label

# %%
plt.plot(x, y, 
         color = 'r',
         marker = 'o',
         linestyle = '--');

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Demo plot')

plt.show();

# %% [markdown]
# ### Scater, bar, hist and box plots

# %%
x, y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 24,  57,  94, 134, 162, 166, 188, 216, 245, 284, 297, 322, 368,
#         380, 424, 472, 521, 567, 571, 602]))

# %%
plt.scatter(x, y,
            linewidths=2,
            )
plt.show();

# %%
b = [10,23, 43, 5, 66]
a = [ 'a', 'b', 'c', 'd', 'e']

plt.bar(a, b,
        width = 0.9)
plt.show();

# %%
plt.hist(y, 
         rwidth = 0.8,
         bins = 30)
plt.show();

# %% [markdown]
# ### Box plot

# %%
# lstcomp

data = [np.random.normal(0, std, 100) for std in range(1, 3)]

# %%
data[1]
# Out:
# array([-2.14243619,  0.80975418,  0.36092714, -1.1262006 ,  1.92577234,
#        -4.60358191,  0.68562691, -1.72443132,  0.92937774, -1.48674171,
#        -2.2267587 , -0.06180237,  1.07044128, -3.24247951, -2.00077659,
#        -1.9803537 ,  1.08850872, -4.43543916,  1.95865666,  0.84960645,
#        -0.37915455,  3.95448425,  1.4672994 ,  3.35248841,  4.00018528,
#        -2.65980252, -0.00797547,  0.74785662,  1.49060281, -0.64301134,
#         1.74014585, -0.32089265, -1.2654247 , -1.47247609, -0.65322278,
#         1.78194045,  2.08664594,  0.71640886, -2.86562203,  2.84000946,
#         1.08574916, -3.21638779,  2.19520505,  0.37963103, -1.34388668,
#         0.76855475, -2.13790061,  3.55736387, -1.11717214, -0.62844496,
#        -2.40474198, -3.80862367,  1.84221523, -0.0511869 ,  0.8591739 ,
#         0.95426302, -1.84098809, -2.92373063, -1.50376621, -0.58942544,
#         1.48776688, -2.11393259,  1.4741803 ,  2.60100345,  1.87407044,
#        -0.22701183, -1.58238214,  2.5964883 , -1.71563333,  2.14592082,
#         0.37419591,  0.09589494,  2.59166272, -0.37777325,  3.423932  ,
#        -1.72088888,  4.83209646, -2.97768488,  5.56747745, -0.11509409,
#        -0.95095433,  4.9021612 , -1.47452146,  0.16291862, -3.44938069,
#        -2.6490837 , -0.14026915, -1.74426036, -2.92388162, -4.33783686,
#         0.17619123,  1.6618444 , -0.69181117,  0.84904734,  0.44263849,
#         0.23615885,  3.81989839,  4.91339017, -1.56136028,  0.08561502])

# %%
plt.boxplot(data, 
            vert = True,
            patch_artist = True)

plt.show();

# %% [markdown]
# ### Subplot

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 24,  57,  94, 134, 162, 166, 188, 216, 245, 284, 297, 322, 368,
#        380, 424, 472, 521, 567, 571, 602])

# %%
y2 = y*x

# %%
plt.plot(y)
plt.plot(y2)

plt.show();

# %%
plt.plot(x, y)
plt.plot(x, y2)

plt.show();

# %%
# row, col, pos

plt.subplot(1, 2, 1)
plt.plot(x, y,
         marker = 'o',
         color = 'g')

plt.subplot(1, 2, 2)
plt.plot(x, y2,
         marker = '*',
         color = 'b',
         markersize = 10)

plt.show();

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.1, 0.6, 0.4, 0.3])

ax1.plot(x, y, 'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Y plot')

ax2.plot(x, y2, 'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y2 Plot')

plt.show();

# %% [markdown]
# ### xlim, ylim, xticks and yticks

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)

ax[1].plot(x, y**2, 'k')

ax[1].set_ylim([0, 5_000])
ax[1].set_xlim([-5, 5])

plt.show();

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)
ax[0].set_xticks([1, 4, 9])

ax[1].plot(x, y**2, 'k')
ax[1].set_xticks([1, 4, 9])
ax[1].set_xticklabels([r'$\alpha$', r'$\beta$', r'$\delta$'])

plt.show();

# %% [markdown]
# ### Pie plot

# %%
# %matplotlib inline

# %%
labels= ['Frogs', 'Cats', 'Dogs', 'Lions']
sizes= [15, 30, 45, 80]

# %%
fig, ax= plt.subplots(figsize= (4, 4),
                      dpi= 100)

explode= (0.1, 0, 0, 0)

ax.pie(sizes, 
       labels= labels,
       autopct= '%1.1f%%',
       shadow= True,
       startangle= 90,
       explode= explode)


plt.show();

# %% [markdown]
# ### Pie plot text color

# %%
fig, ax= plt.subplots(figsize= (4, 4),
                      dpi= 100)

explode= (0.1, 0, 0, 0)

patches, texts, autotexts= ax.pie(sizes, 
                                  labels= labels,
                                  autopct= '%1.1f%%',
                                  shadow= True,
                                  startangle= 90,
                                  explode= explode)

plt.setp(autotexts, 
         size= 14,
         color= 'black')

autotexts[0].set_color('white')
autotexts[1].set_color('blue')

plt.show();

# %% [markdown]
# ### Nested pie chart

# %%
fig, ax= plt.subplots(dpi= 100)
size= 0.3

vals= np.array([[60, 32],
               [35, 20],
               [26, 36]])

vals_sum= vals.sum(axis= 1)
vals_flat= vals.flatten()

cmap= plt.get_cmap('tab20c')

outer_colors= cmap(np.arange(3)* 8)
inner_colors= cmap(np.arange(6)* 12)

ax.pie(vals_sum, 
       radius= 1,
       colors= outer_colors,
       wedgeprops= dict(width= size,
                        edgecolor= 'w'))

ax.pie(vals_flat, 
       radius= 1- size,
       colors= inner_colors,
       wedgeprops= dict(width= size,
                        edgecolor= 'w'));

# %% [markdown]
# ### Labeling a pie chart

# %%
fig, ax= plt.subplots(dpi= 150)
recipe= ['375 g Flour', '75 g Suger', '250 g Butter', '300 g Berries']

data= [ float(x.split(' ')[0]) for x in recipe]
ingredients= [ x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute= int(pct/ 100.* np.sum(vals))
    return '{:.1f}%\n({:d} g)'.format(pct, absolute)

wedges, texts, autotextes= ax.pie(data, 
                                  autopct= lambda pct: func(pct, data),
                                  textprops= dict(color= 'w'))

ax.legend(wedges, 
          ingredients,
          title= 'Ingredients',
          loc= 'center left',
          bbox_to_anchor= (1, 0, 1, 1))

plt.show();

# %% [markdown]
# ### Bar chart on polar axis

# %%
np.random.seed(0)
N= 20
theta= np.linspace(0.0, 
                   2*np.pi, 
                   N, 
                   endpoint= False)

radii= 10* np.random.rand(N)
width= np.pi/ 4* np.random.rand(N)
colors= plt.cm.plasma(radii/ 10)

plt.figure(dpi= 100)
ax= plt.subplot(1, 1, 1, projection= 'polar')

ax.bar(theta, 
       radii,
       width= width, 
       bottom= 0,
       color= colors,
       alpha= 0.7)

plt.show();

# %% [markdown]
# ### Line plot on a polar axis

# %%
r= np.arange(0, 2, 0.01)
theta= 2* np.pi* r

plt.figure(dpi= 100)

ax= plt.subplot(111, projection= 'polar')
ax.plot(theta, r)

ax.set_rmax(2)
ax.set_rticks([0, 0.5, 1, 1.5])
ax.set_rlabel_position(-30)
ax.grid(True)

plt.show()

# %% [markdown]
# ### Scater plot on polar axis

# %%
np.random.seed(0)

N= 150
r= 2* np.random.rand(N)
theta= 2* np.pi* np.random.rand(N)
area= 50* 2* np.pi* r** 2
colors= theta

fig= plt.figure(dpi= 100)
ax= fig.add_subplot(111, projection= 'polar')

c= ax.scatter(theta, 
            r, 
            c= colors, 
            s= area,
            cmap= 'hsv',
            alpha= 0.8)

plt.show()

# %% [markdown]
# ### Integral as the area under a curve

# %%
from matplotlib.patches import Polygon

# %%
def func(x):
    return (x- 3)* (x-5 )* (x- 7)+ 85

a,b = 2, 9

x= np.linspace(0, 10)
y= func(x)

fig, ax= plt.subplots(dpi= 100)

ax.plot(x, y, 'b',
        linewidth= 2)
ax.set_ylim(bottom= 0)

ix= np.linspace(a, b)
iy= func(ix)

verts= [(a, 0), *zip(ix, iy), (b, 0)]
poly= Polygon(verts, 
              facecolor= '0.9', 
              edgecolor= '0.5')
ax.add_patch(poly)

ax.text(0.5* (a+ b), 30, 
        r"$\int_a^b f(x)d(x)$",
        horizontalalignment= 'center',
        fontsize= 20)

fig.text(0.9, 0.05, 'x')
fig.text(0.1, 0.9, 'y')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a, b))
ax.set_xticklabels(('a', 'b'))
ax.set_yticks([])

plt.show();

# %% [markdown]
# ### Real-time CPU uses plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.animation import FuncAnimation

from psutil import cpu_percent

# %%
cpu_percent()
# Out:
# 25.4

# %%
uses= []

# %%
cpu_use= cpu_percent()
uses.append(cpu_use) 
print(cpu_use)
# Out:
# 17.5

# %%
print(uses)
# Out:
# [17.5]

# %%
plt.plot(uses)

plt.show();

# %%
# %matplotlib notebook

frame_len = 200

y= []
fig= plt.figure(figsize= (8, 4))

def animate(i):
    y.append(cpu_percent())
    
    if len(y) <= frame_len:
        plt.cla()
        plt.plot(y, 'r', label= 'Real-Time CPU Uses')
    
    else:
        plt.cla()
        plt.plot(y[-frame_len: ], 'r', label= 'Real-Time CPU Uses')
        
    plt.ylim(0, 100)
    plt.xlabel('Time (s)')
    plt.ylabel('CPU Uses (%)')
    plt.legend(loc= 'upper right')
    plt.tight_layout()

    

ani= FuncAnimation(plt.gcf(), 
                   animate, 
                   interval= 1000)   #1 sec

plt.show()
# Out:
# <div id='7b2dc147-2eba-45cc-85e8-96358a70a6a0'></div>

# %% [markdown]
# ### End.
