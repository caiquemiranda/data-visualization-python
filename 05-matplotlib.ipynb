# %% [markdown]
# ## Matplotlib

# %%
# Versão da Linguagem Python

from platform import python_version
print('Versão de Python Neste Jupyter Notebook:', python_version())
# Out:
# Versão de Python Neste Jupyter Notebook: 3.10.5

# %%
#imports necessários

import numpy as np                    # manipulação numerica
import matplotlib.pyplot as plt       # visualização gráfica
import matplotlib
from numpy.random import randint


import warnings                       # silecio de alertas
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
print('Author: Caique Miranda')
print('Github username: caiquemiranda')
print('\n')
# versões utilizadas nesse Notebook.

print(f'Versão do Numpy {np.__version__}')
print(f'Versão do Matplotlib {matplotlib.__version__}')
# Out:
# Author: Caique Miranda
# Github username: caiquemiranda
#
#
# Versão do Numpy 1.23.0
# Versão do Matplotlib 3.5.2

# %% [markdown]
# ### Plot

# %%
# !pip install matplotlib

# %%
x = np.linspace(1, 10, 20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1, 50, 20)
y
# Out:
# array([41,  4, 48, 30, 24,  1, 33, 41,  3,  5, 16,  7, 31, 27,  1, 26, 14,
#        42, 20, 18])

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
plt.plot(y);

# %%
y = y.cumsum()

# %%
plt.plot(y);

# %%
plt.plot(x, y);

# %%
plt.plot(x, y, 
         color = 'g',
         marker = 'o',
         linestyle = '--');

# %% [markdown]
# ### Label

# %%
plt.plot(x, y, 
         color = 'r',
         marker = 'o',
         linestyle = '--');

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Demo plot')

plt.show();

# %% [markdown]
# ### Scater, bar, hist and box plots

# %%
x, y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 41,  45,  93, 123, 147, 148, 181, 222, 225, 230, 246, 253, 284,
#         311, 312, 338, 352, 394, 414, 432]))

# %%
plt.scatter(x, y,
            linewidths=2,
            )
plt.show();

# %%
b = [10,23, 43, 5, 66]
a = [ 'a', 'b', 'c', 'd', 'e']

plt.bar(a, b,
        width = 0.9)
plt.show();

# %%
plt.hist(y, 
         rwidth = 0.8,
         bins = 30)
plt.show();

# %% [markdown]
# ### Box plot

# %%
# lstcomp

data = [np.random.normal(0, std, 100) for std in range(1, 3)]

# %%
data[1]
# Out:
# array([ 1.90123055e+00, -7.79420551e-01,  1.61641031e+00, -1.76215367e+00,
#        -1.19811742e+00, -5.21049699e+00, -3.60914679e-01, -2.52893880e+00,
#         1.32568565e-03,  1.14119812e+00,  8.16914687e-01, -5.53472708e-01,
#         1.63990789e+00,  2.40107142e+00, -3.25592776e-01,  4.24901260e+00,
#         1.31011860e+00,  2.11107157e+00,  3.77936914e+00, -1.70416540e+00,
#         3.21079177e-01,  6.37829269e-01,  9.96276707e-02, -1.75471318e+00,
#         5.28234671e-01,  1.26369658e+00,  2.45307376e-01,  7.62936530e-01,
#         8.45804207e-01,  3.17826536e+00,  1.46951978e+00,  1.85223575e+00,
#        -3.43570188e+00,  8.23149068e-01, -1.90999077e+00,  4.11096412e-01,
#        -3.58855927e+00,  1.05411662e+00,  2.52151608e+00, -3.23029716e+00,
#         1.72653688e+00,  6.62147982e-01,  1.53619180e+00, -2.09304824e+00,
#         8.42520978e-01, -4.31883940e+00,  6.39512118e-01,  1.10556036e+00,
#        -4.78189079e-01,  2.59359136e+00,  9.30709931e-01,  6.77931540e-01,
#        -1.35234196e+00,  1.72537908e+00,  3.30362382e+00,  2.98423578e-01,
#        -1.19931607e-01,  3.85018427e+00,  4.66181968e+00, -1.43082566e+00,
#        -1.75952852e+00, -6.92713027e-01, -1.45866420e+00, -6.78729455e-01,
#         1.58342807e+00, -3.52329676e+00, -1.70166985e+00, -1.66579894e+00,
#         4.03828145e+00,  3.77316161e+00, -6.36593708e-01,  3.04349822e+00,
#        -2.09498313e+00,  1.70634581e+00, -2.15337016e-01,  2.85801812e+00,
#        -2.68008553e-01,  3.01368661e+00,  7.60992607e-01, -2.41631908e+00,
#         2.60532049e+00, -1.61125977e+00, -1.45740545e-01, -3.89860577e-01,
#         1.28455728e+00, -8.40794789e-01,  2.34503632e+00,  1.32453777e+00,
#         1.12114508e+00, -4.16225119e-01, -1.43895274e+00,  1.72654008e-01,
#        -1.79571974e+00, -1.06538397e+00, -1.35195679e+00,  5.78309727e-01,
#         2.22349731e+00,  1.97046570e+00,  1.22894163e+00,  7.23470593e-01])

# %%
plt.boxplot(data, 
            vert = True,
            patch_artist = True)

plt.show();

# %% [markdown]
# ### Subplot

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 41,  45,  93, 123, 147, 148, 181, 222, 225, 230, 246, 253, 284,
#        311, 312, 338, 352, 394, 414, 432])

# %%
y2 = y*x

# %%
plt.plot(y)
plt.plot(y2)

plt.show();

# %%
plt.plot(x, y)
plt.plot(x, y2)

plt.show();

# %%
# row, col, pos

plt.subplot(1, 2, 1)
plt.plot(x, y,
         marker = 'o',
         color = 'g')

plt.subplot(1, 2, 2)
plt.plot(x, y2,
         marker = '*',
         color = 'b',
         markersize = 10)

plt.show();

# %%
fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.1, 0.6, 0.4, 0.3])

ax1.plot(x, y, 'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Y plot')

ax2.plot(x, y2, 'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y2 Plot')

plt.show();

# %% [markdown]
# ### xlim, ylim, xticks and yticks

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)

ax[1].plot(x, y**2, 'k')

ax[1].set_ylim([0, 5_000])
ax[1].set_xlim([-5, 5])

plt.show();

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)
ax[0].set_xticks([1, 4, 9])

ax[1].plot(x, y**2, 'k')
ax[1].set_xticks([1, 4, 9])
ax[1].set_xticklabels([r'$\alpha$', r'$\beta$', r'$\delta$'])

plt.show();

# %% [markdown]
# ### Pie plot

# %%
# %matplotlib inline

# %%
labels= ['Frogs', 'Cats', 'Dogs', 'Lions']
sizes= [15, 30, 45, 80]

# %%
fig, ax= plt.subplots(figsize= (4, 4),
                      dpi= 100)

explode= (0.1, 0, 0, 0)

ax.pie(sizes, 
       labels= labels,
       autopct= '%1.1f%%',
       shadow= True,
       startangle= 90,
       explode= explode)


plt.show();

# %% [markdown]
# ### Pie plot text color

# %%
fig, ax= plt.subplots(figsize= (4, 4),
                      dpi= 100)

explode= (0.1, 0, 0, 0)

patches, texts, autotexts= ax.pie(sizes, 
                                  labels= labels,
                                  autopct= '%1.1f%%',
                                  shadow= True,
                                  startangle= 90,
                                  explode= explode)

plt.setp(autotexts, 
         size= 14,
         color= 'black')

autotexts[0].set_color('white')
autotexts[1].set_color('blue')

plt.show();

# %% [markdown]
# ### Nested pie chart

# %%
fig, ax= plt.subplots(dpi= 100)
size= 0.3

vals= np.array([[60, 32],
               [35, 20],
               [26, 36]])

vals_sum= vals.sum(axis= 1)
vals_flat= vals.flatten()

cmap= plt.get_cmap('tab20c')

outer_colors= cmap(np.arange(3)* 8)
inner_colors= cmap(np.arange(6)* 12)

ax.pie(vals_sum, 
       radius= 1,
       colors= outer_colors,
       wedgeprops= dict(width= size,
                        edgecolor= 'w'))

ax.pie(vals_flat, 
       radius= 1- size,
       colors= inner_colors,
       wedgeprops= dict(width= size,
                        edgecolor= 'w'));

# %% [markdown]
# ### Labeling a pie chart

# %%
fig, ax= plt.subplots(dpi= 150)
recipe= ['375 g Flour', '75 g Suger', '250 g Butter', '300 g Berries']

data= [ float(x.split(' ')[0]) for x in recipe]
ingredients= [ x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute= int(pct/ 100.* np.sum(vals))
    return '{:.1f}%\n({:d} g)'.format(pct, absolute)

wedges, texts, autotextes= ax.pie(data, 
                                  autopct= lambda pct: func(pct, data),
                                  textprops= dict(color= 'w'))

ax.legend(wedges, 
          ingredients,
          title= 'Ingredients',
          loc= 'center left',
          bbox_to_anchor= (1, 0, 1, 1))

plt.show();

# %% [markdown]
# ### Bar chart on polar axis

# %%
np.random.seed(0)
N= 20
theta= np.linspace(0.0, 
                   2*np.pi, 
                   N, 
                   endpoint= False)

radii= 10* np.random.rand(N)
width= np.pi/ 4* np.random.rand(N)
colors= plt.cm.plasma(radii/ 10)

plt.figure(dpi= 100)
ax= plt.subplot(1, 1, 1, projection= 'polar')

ax.bar(theta, 
       radii,
       width= width, 
       bottom= 0,
       color= colors,
       alpha= 0.7)

plt.show();

# %% [markdown]
# ### Line plot on a polar axis

# %%
r= np.arange(0, 2, 0.01)
theta= 2* np.pi* r

plt.figure(dpi= 100)

ax= plt.subplot(111, projection= 'polar')
ax.plot(theta, r)

ax.set_rmax(2)
ax.set_rticks([0, 0.5, 1, 1.5])
ax.set_rlabel_position(-30)
ax.grid(True)

plt.show()

# %% [markdown]
# ### Scater plot on polar axis

# %%
np.random.seed(0)

N= 150
r= 2* np.random.rand(N)
theta= 2* np.pi* np.random.rand(N)
area= 50* 2* np.pi* r** 2
colors= theta

fig= plt.figure(dpi= 100)
ax= fig.add_subplot(111, projection= 'polar')

c= ax.scatter(theta, 
            r, 
            c= colors, 
            s= area,
            cmap= 'hsv',
            alpha= 0.8)

plt.show()

# %% [markdown]
# ### Integral as the area under a curve

# %%
from matplotlib.patches import Polygon

# %%
def func(x):
    return (x- 3)* (x-5 )* (x- 7)+ 85

a,b = 2, 9

x= np.linspace(0, 10)
y= func(x)

fig, ax= plt.subplots(dpi= 100)

ax.plot(x, y, 'b',
        linewidth= 2)
ax.set_ylim(bottom= 0)

ix= np.linspace(a, b)
iy= func(ix)

verts= [(a, 0), *zip(ix, iy), (b, 0)]
poly= Polygon(verts, 
              facecolor= '0.9', 
              edgecolor= '0.5')
ax.add_patch(poly)

ax.text(0.5* (a+ b), 30, 
        r"$\int_a^b f(x)d(x)$",
        horizontalalignment= 'center',
        fontsize= 20)

fig.text(0.9, 0.05, 'x')
fig.text(0.1, 0.9, 'y')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.xaxis.set_ticks_position('bottom')
ax.set_xticks((a, b))
ax.set_xticklabels(('a', 'b'))
ax.set_yticks([])

plt.show();

# %% [markdown]
# ### Real-time CPU uses plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.animation import FuncAnimation

from psutil import cpu_percent

# %%
cpu_percent()
# Out:
# 20.9

# %%
uses= []

# %%
cpu_use= cpu_percent()
uses.append(cpu_use) 
print(cpu_use)
# Out:
# 40.7

# %%
print(uses)
# Out:
# [40.7]

# %%
plt.plot(uses)

plt.show();

# %%
# %matplotlib notebook

frame_len = 200

y= []
fig= plt.figure(figsize= (8, 4))

def animate(i):
    y.append(cpu_percent())
    
    if len(y) <= frame_len:
        plt.cla()
        plt.plot(y, 'r', label= 'Real-Time CPU Uses')
    
    else:
        plt.cla()
        plt.plot(y[-frame_len: ], 'r', label= 'Real-Time CPU Uses')
        
    plt.ylim(0, 100)
    plt.xlabel('Time (s)')
    plt.ylabel('CPU Uses (%)')
    plt.legend(loc= 'upper right')
    plt.tight_layout()

    

ani= FuncAnimation(plt.gcf(), 
                   animate, 
                   interval= 1000)   #1 sec

plt.show()
# Out:
# <div id='f4a00c1f-9e1d-4327-8e9f-f7fe2eecd59d'></div>

# %% [markdown]
# ### End.
