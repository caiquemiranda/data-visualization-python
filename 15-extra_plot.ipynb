# %% [markdown]
# #### Gallery for Matplotlib
#
# link -> https://matplotlib.org/gallery/index.html
#
# ---
# #### Gallery for Seaborn
#
# link -> https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# Example 1.

# %%
# The code below draws the sine function for x 2 »0; 2¼

# imports
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.linspace(0, 2*math.pi, 1000)    # Create a regularly spaced sequence
y = np.sin(x)                          # Calculate sine

plt.figure()                           # Create a new figure
plt.plot(x, y);                         # Draw line plot

#plt.close()                           # Close plot and free up resources

# %% [markdown]
# Example 2.

# %%
# We can produce a scatter plot using green circles as markers using

x = np.random.standard_normal(100)                   # Create a random data cloud
y = x + np.random.standard_normal(100)

plt.plot(x, y, marker=".", color="g", linestyle="")  # Draw scatter plot
plt.show()                                           # show plot

# %% [markdown]
# Assignment 1.

# %%
# Create a plot of the exponential function for x 2 »􀀀3; 3¼. Change the colour to magenta and the line to be dashed. The plot should look like the one shown below.

# %% [markdown]
# Example 3.

# %%
# We can plot a sine function with added noise using the following code.

x = np.linspace(0, 2*math.pi, 1000)           # Create a regularly spaced sequence
y = np.sin(x)                                 # Calculate sine

y_noisy = y + np.random.standard_normal(1000) # Create noisy version of y

plt.plot(x, y, "g")                           # Draw line
plt.plot(x, y_noisy, "m.")                    # Add noisy points
plt.show()                                    # Show the plot

# %%
x = np.linspace(0, 2*math.pi, 1000)              # Create a regularly spaced sequence
y = np.sin(x)                                    # Calculate sine

y_noisy = y + np.random.standard_normal(1000)    # Create noisy version of y

plt.plot(x, y, "g", x, y_noisy, "m.")            # Draw everything in one go
plt.show()                                       # Show the plot

# %% [markdown]
# Example 4.

# %%
# We can plot the petal width against the petal length in the iris data set (from the le iris.csv (available
# from http://www.stats.gla.ac.uk/~levers/dpip/iris.csv) using the following code.

import pandas as pd
iris = pd.read_csv("data/iris.csv")                          # Read in iris data from csv

plt.plot("PetalLengthCm", "PetalWidthCm", ".", data=iris) # Plot from data frame
plt.show()                                              # Show the plot
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\inputtransformer2.py:595: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   tokens_by_line = make_tokens_by_line(lines)

# %% [markdown]
# Example 5.

# %%
colours = iris["Species"].map({"Iris-setosa": "blue",           # Manually map species to colours
                               "Iris-virginica": "purple",
                               "Iris-versicolor": "teal"})

plt.scatter("PetalLengthCm", "PetalWidthCm", c=colours, data=iris)
plt.show()                                                        # show plot

# %% [markdown]
# Example 6.

# %% [markdown]
# <p>We can create a box plot of the distribution of the petal length for the three species in the iris data set in
# two ways.</p>
#
# <p>One consists of creating a list in which each element is a series containing the petal length measurements
# for one species.</p>

# %%
pl_by_species = list(map(lambda x:iris.query("Species=='{}'".format(x))["PetalLengthCm"],
                        ["Iris-setosa", "Iris-versicolor", "Iris-virginica"]))

# We can then produce the box plots.

plt.boxplot(pl_by_species, labels=["Iris-setosa", "Iris-versicolor", "Iris-virginica"])

plt.show() # Show plot

# %%
plt.boxplot(iris.query("Species=='Iris-setosa'")["PetalLengthCm"].values, positions=[1])

plt.boxplot(iris.query("Species=='Iris-versicolor'")["PetalLengthCm"].values, positions=[2])

plt.boxplot(iris.query("Species=='Iris-virginica'")["PetalLengthCm"].values, positions=[3])

plt.xticks([1,2,3], ["Setosa", "Versicolor", "Virginica"])

plt.xlim(0.5,3.5) # Fix horizontal

plt.show()

# %% [markdown]
# Example 7.

# %% [markdown]
# The code below produces a histogram showcasing the differences between the distribution of the petal
# lengths between the three species.

# %%
plt.hist(pl_by_species, color=["blue", "purple", "teal"], alpha=0.5, histtype="stepfilled")

plt.show()

# %%
# plots
plt.hist(iris.query("Species=='Iris-setosa'")["PetalLengthCm"], color="blue", alpha=0.5)
plt.hist(iris.query("Species=='Iris-versicolor'")["PetalLengthCm"], color="purple", alpha=0.5)
plt.hist(iris.query("Species=='Iris-virginica'")["PetalLengthCm"], color="teal", alpha=0.5)

plt.legend(labels = ["Setosa", "Versicolor", "Virginica"])

plt.show()

# %% [markdown]
# Example 8.

# %%
counts = iris.groupby("Species").apply(lambda x: x.shape[0])

# We can then draw a bar chart. bar requires the specification of both horizontal positions and heights.
# We will set the former to [1,2,3] and then replace the numerical horizontal axis by a categorical one.

plt.bar([1,2,3], counts, color=["blue", "purple", "teal"])
plt.xticks([1,2,3], ["Setosa", "Versicolor", "Virginica"])

plt.show()

# %%
plt.pie(counts, colors=["blue", "purple", "teal"], labels=["Setosa", "Versicolor", "Virginica"])

plt.axis('equal') # Force equal scales, so that circle looks like a circle
plt.show()

# %% [markdown]
# Example 9.

# %%
x = np.linspace(-2, 2, 100) # Create sequence of x's
y = np.linspace(-2, 2, 100) # Create sequence of y's

Z = x[None,:] * np.exp(-x[None,:]**2 - y[:,None]**2)

# We could have also used the NumPy function meshgrid to create Z

X,Y = np.meshgrid(x, y) # Expand x and y into matrices

# x row-wise and y column-wise

Z = X * np.exp(-X**2 - Y**2) # Define Z in terms of matrices

plt.contour(x, y, Z, 50, cmap='RdGy') # Draw contour lines
plt.show()

# %%
plt.contourf(x, y, Z, 20, cmap='Spectral') # Add contour lines
plt.colorbar() # Add a colour bar as legend

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D # Load required module

ax = plt.axes(projection="3d") # Set up plot to be 3d
ax.plot_surface(X, Y, Z, cmap="Spectral", edgecolor="black")

# Draw surface plot
plt.show()

# %% [markdown]
# Example 10.

# %%
# This example illustrates the use of title, xlim, ylim, xlabel, and ylabel.

x = np.linspace(0, 2*math.pi, 1000) # Create sequence from 0 to 2*pi

plt.plot(x, np.sin(x)) # Draw plot

plt.xlim(-1, 8) # Set limits of horizontal axis
plt.ylim(-2, 2) # Set limits of vertical axis

plt.xlabel("x") # Set horizontal axis label
plt.ylabel("sin(x)") # Set vertical axis label
plt.title("The sine function") # Set plot title

plt.show()

# %% [markdown]
# Example 11.

# %%
# This example illustrates how to add vertical or horizontal lines.

x = np.linspace(0, 2*math.pi, 1000) # Create sequence from 0 tp 2*pi

plt.plot(x, np.sin(x)) # Draw plot

plt.axhline(0, linestyle="-", linewidth=0.5) # Horizontal line at 0
plt.axvline(math.pi, linestyle="-", linewidth=0.5) # Vertical line at pi

plt.show()

# %% [markdown]
# Example 12.

# %%
x = np.linspace(0, 2*math.pi, 1000) # Create sequence from 0 t 2*pi

plt.plot(x, np.sin(x), "g-", label="sin(x)") # Draw plot of sine function
plt.plot(x, np.cos(x), "m-", label="cos(x)") # Draw plot of cosine function

plt.legend() # Add a legend

plt.show()

# %%
plt.style.use('fivethirtyeight') # Use theme fivethirtyeight

x = np.linspace(0, 2*math.pi, 1000) # Create sequence from 0 to 2*pi

plt.plot(x, np.sin(x), x, np.cos(x)) # Draw both lines in one go
plt.legend(labels=["sin(x)", "cos(x)"]) # Add a legend

plt.show()

# %%
plt.figure(figsize=[9,4]) # Create new figure (wider than normal)

x = np.linspace(0, 2*math.pi, 1000) # Create a regularly spaced sequence

plt.subplot(1, 2, 1) # Use first plot in row of two plots
plt.plot(x, np.sin(x)) # Plot sine function
plt.title("sin(x)") # Add title
plt.subplot(1, 2, 2) # Use second plot in row of two plots
plt.plot(x, np.cos(x)) # Plot cosine function
plt.title("cos(x)") # Add title

plt.show()

# %% [markdown]
# Example 14.

# %%
x = np.linspace(0, 2*math.pi, 1000) # Create a regularly spaced sequence

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
# Split the plotting region and share y axis

ax1.plot(x, np.sin(x)) # Plot sine function
ax1.set_title("sin(x)") # Add title
ax2.plot(x, np.cos(x)) # Plot cosine function
ax2.set_title("cos(x)") # Add title

plt.show()

# %%
# The code below illustrates how to save a plot to a PDF file.

x = np.linspace(0, 2*math.pi, 1000) # Create sequence from 0 to 2*pi

plt.plot(x, np.sin(x), "g-", x, np.cos(x), "m-")

# Draw both lines in one go
plt.legend(labels=["sin(x)", "cos(x)"]) # Add a legend

plt.savefig("data/trigonometric_functions.pdf")

# %% [markdown]
# Example 16.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot("PetalWidthCm", "PetalLengthCm", hue="Species", data=iris)

plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Example 17.

# %%
import numpy as np
import pandas as pd
import math

data = pd.DataFrame({"x": np.linspace(0, 2*math.pi, 1000)})
data = data.eval("sine = sin(x)")
data = data.eval("cosine = cos(x)")

# In order to be able to plot sine and cosine in a single seaborn plot we convert the data from wide format for long format.

data=data.melt(id_vars=["x"], value_vars=["sine","cosine"],

var_name="Function", value_name="f(x)")

sns.relplot("x", "f(x)", hue="Function", data=data, kind="line")
plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Example 18.

# %%
sns.relplot("PetalWidthCm", "PetalLengthCm", hue="Species", col="Species", col_wrap=2, data=iris)
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Example 19.

# %%
sns.catplot("Species", "PetalLengthCm", hue="Species", data=iris, kind="swarm")
plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Example 10.

# %%
sns.distplot(iris["PetalWidthCm"], rug=True)
plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
grid = sns.FacetGrid(iris, col="Species", col_wrap=2, hue="Species")
grid.map(sns.distplot, "PetalWidthCm", rug=True)
plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Example 21.

# %%
sns.jointplot("PetalLengthCm", "PetalWidthCm", data=iris, kind="kde")
plt.show()
# Out:
# c:\Users\Caíque Miranda\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Examples 22.

# %%
sns.pairplot(iris, hue="Species")
plt.show()

# %% [markdown]
# Examples 23.

# %%
import matplotlib.pyplot as plt
import pandas as pd

population = pd.Series( [ 196670, 148270, 464990, 621020, 63780, 47180, 94000 ] ,

index = ["Aberdeen", "Dundee", "Edinburgh", "Glasgow", "Inverness", "Perth", "Stirling"] )

population.plot.bar() # Create bar plot of values

# population.plot(kind="bar") # Equivalent alternative

plt.subplots_adjust(bottom=0.2) # Increase margin at the bottom
plt.show()

# %% [markdown]
# Example 24.

# %%
iris.plot.box()
plt.show()

# %%
iris.plot.scatter("PetalLengthCm", "PetalWidthCm")
plt.show()

# %%
iris.plot.hexbin("PetalLengthCm", "PetalWidthCm", gridsize=(20,15))
plt.show()

# %% [markdown]
# Example 25.

# %%
pd.plotting.scatter_matrix(iris)
plt.show()

# %%
pd.plotting.parallel_coordinates(iris, "Species")
plt.show()

# %%
# %reload_ext watermark
# %watermark -a "Caique Miranda" -gu "caiquemiranda" -iv
# Out:
# Author: Caique Miranda
#
# Github username: caiquemiranda
#
# numpy     : 1.23.0
# matplotlib: 3.5.2
# sys       : 3.10.5 (tags/v3.10.5:f377153, Jun  6 2022, 16:14:13) [MSC v.1929 64 bit (AMD64)]
# seaborn   : 0.11.2
# pandas    : 1.4.3

# %% [markdown]
# ### End
